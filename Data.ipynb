# %%
import pandas as pd

# %%
# Csv file to load
LAParkingCitationData=pd.read_csv("Data/LAPsampledata.csv")
LAParkingCitationData.head()
# Out:
#    Ticket number           Issue Date  Issue time Meter Id  Marked Time  \
# 0     4297600543  2016-11-06T00:00:00       746.0      NaN          NaN
# 1     4351910846  2019-04-02T00:00:00      1803.0      NaN          NaN
# 2     4304968275  2017-03-16T00:00:00      1904.0      NaN          NaN
# 3     4295311462  2016-10-27T00:00:00      1359.0      NaN          NaN
# 4     4278878494  2016-03-18T00:00:00      2309.0      NaN          NaN
#
#   RP State Plate  Plate Expiry Date  VIN  Make Body Style Color  \
# 0             CA           201612.0  NaN  CHEV         PA    GY
# 1             CA           201912.0  NaN  HOND         PA    GY
# 2             CA           201706.0  NaN  FORD         PA    RD
# 3             CA           201708.0  NaN  NISS         PA    GY
# 4             CA                NaN  NaN  INFI         PA    GY
#
#              Location  Route  Agency Violation code Violation Description  \
# ...

# %%
LAParkingCitationData=LAParkingCitationData.drop(['Meter Id','Marked Time','Plate Expiry Date','VIN','Route','Agency'],axis=1)

# %%
LADf=LAParkingCitationData.head(100)

# %%
LADf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
# Ticket number            100 non-null int64
# Issue Date               100 non-null object
# Issue time               100 non-null float64
# RP State Plate           100 non-null object
# Make                     100 non-null object
# Body Style               100 non-null object
# Color                    100 non-null object
# Location                 100 non-null object
# Violation code           100 non-null object
# Violation Description    100 non-null object
# Fine amount              100 non-null float64
# Latitude                 100 non-null float64
# Longitude                100 non-null float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 10.2+ KB

# %%
LADf.to_html("LAData.html")
